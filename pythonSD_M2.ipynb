# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print('librairies loaded')
# Out:
# librairies loaded

# %%
houses = pd.read_csv('datas/house_pricing.csv');
houses.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
houses.head(12)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
#
# ...

# %%
houses['LotArea']
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
houses.LotArea
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
houses.LotArea.mean()
# Out:
# 10516.828082191782

# %%
filter1 = houses[ houses['LotArea'] < 1500 ]
filter1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 614          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 956          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 1039         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 614       5   2010        WD         Normal      75500
# 956       5   2009        WD         Normal     124000
# 1039      4   2009        WD         Normal      80000
#
# [3 rows x 81 columns]

# %%
filter2 = filter1[filter1['SalePrice'] < 120000 ]
filter2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 614          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1039         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 614       5   2010        WD         Normal      75500
# 1039      4   2009        WD         Normal      80000
#
# [2 rows x 81 columns]

# %%
filter_cumulate = houses[(houses['LotArea'] < 1500)&(houses['SalePrice']<120000)]
filter_cumulate
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 614          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1039         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 614       5   2010        WD         Normal      75500
# 1039      4   2009        WD         Normal      80000
#
# [2 rows x 81 columns]

# %%
sns.relplot(x="LotArea",y="SalePrice",data=filter_cumulate)

# %%
sns.relplot(x="LotArea",y="SalePrice",data=houses)

# %%
sns.relplot(x="LotArea",y="SalePrice",data=houses.query("LotArea < 1500"))

# %%
houses.isNull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3260/2717297292.py in <module>
# ----> 1 houses.isNull()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'isNull'

# %%
houses.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
houses.isna()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
houses.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
null = houses[houses.isna().sum().sort_values(ascending=False)[0:4].index.tolist()]
null
# Out:
#      PoolQC MiscFeature Alley  Fence
# 0       NaN         NaN   NaN    NaN
# 1       NaN         NaN   NaN    NaN
# 2       NaN         NaN   NaN    NaN
# 3       NaN         NaN   NaN    NaN
# 4       NaN         NaN   NaN    NaN
# ...     ...         ...   ...    ...
# 1455    NaN         NaN   NaN    NaN
# 1456    NaN         NaN   NaN  MnPrv
# 1457    NaN        Shed   NaN  GdPrv
# 1458    NaN         NaN   NaN    NaN
# 1459    NaN         NaN   NaN    NaN
#
# [1460 rows x 4 columns]

# %%
null.dropna(how='any')
null
# Out:
#      PoolQC MiscFeature Alley  Fence
# 0       NaN         NaN   NaN    NaN
# 1       NaN         NaN   NaN    NaN
# 2       NaN         NaN   NaN    NaN
# 3       NaN         NaN   NaN    NaN
# 4       NaN         NaN   NaN    NaN
# ...     ...         ...   ...    ...
# 1455    NaN         NaN   NaN    NaN
# 1456    NaN         NaN   NaN  MnPrv
# 1457    NaN        Shed   NaN  GdPrv
# 1458    NaN         NaN   NaN    NaN
# 1459    NaN         NaN   NaN    NaN
#
# [1460 rows x 4 columns]

# %%
null.dropna(how='any', subset=['PoolQC'])
null
# Out:
#      PoolQC MiscFeature Alley  Fence
# 197      Ex         NaN   NaN  GdPrv
# 810      Fa         NaN   NaN  GdPrv
# 1170     Gd         NaN   NaN  GdPrv
# 1182     Ex         NaN   NaN  MnPrv
# 1298     Gd         NaN   NaN    NaN
# 1386     Fa        TenC   NaN  MnPrv
# 1423     Gd         NaN   NaN  GdPrv

# %%
null.MiscFeature.fillna('Unknown')
null
# Out:
#      PoolQC MiscFeature Alley  Fence
# 197      Ex         NaN   NaN  GdPrv
# 810      Fa         NaN   NaN  GdPrv
# 1170     Gd         NaN   NaN  GdPrv
# 1182     Ex         NaN   NaN  MnPrv
# 1298     Gd         NaN   NaN    NaN
# 1386     Fa        TenC   NaN  MnPrv
# 1423     Gd         NaN   NaN  GdPrv

# %%
houses.dropna(subset=["PoolQC"], inplace=True)
houses
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1170  1171          80       RL         76.0     9880   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 810          Lvl    AllPub  ...      648     Fa  GdPrv         NaN       0
# 1170         Lvl    AllPub  ...      576     Gd  GdPrv         NaN       0
# ...

# %%
houses
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1170  1171          80       RL         76.0     9880   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 810          Lvl    AllPub  ...      648     Fa  GdPrv         NaN       0
# 1170         Lvl    AllPub  ...      576     Gd  GdPrv         NaN       0
# ...
